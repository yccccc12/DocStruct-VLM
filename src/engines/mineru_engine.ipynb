# %% [markdown]
# ## Using Command Line (mineru)

# %%
from google.colab import drive
import zipfile

# Mount Drive
drive.mount('/content/drive')

zip_path = "/content/drive/MyDrive/data.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade pip
# !pip install uv
# !uv pip install -U "mineru[all]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 86.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 96.8 MB/s  0:00:00
# ...
# Using Python 3.12.12 environment at: /usr
# Resolved 217 packages in 1.39s
# Prepared 101 packages in 40.17s
# Uninstalled 39 packages in 1.77s
# Installed 101 packages in 1.20s
#  + astor==0.8.1
#  - attrs==25.4.0
#  + attrs==26.1.0
#  + av==17.0.0
#  - beautifulsoup4==4.13.5
#  + beautifulsoup4==4.14.3
#  + blake3==1.0.8
#  + boto3==1.42.73
#  + botocore==1.42.73
#  - cachetools==6.2.6
#  + cachetools==7.0.5
#  + cbor2==5.8.0
#  + colorlog==6.10.1
#  + compressed-tensors==0.11.0
#  - cryptography==43.0.3
#  + cryptography==46.0.5
#  + depyf==0.19.0
#  - dill==0.3.8
#  + dill==0.4.1
#  + diskcache==5.6.3
#  + dnspython==2.8.0
#  + doclayout-yolo==0.0.4
#  + email-validator==2.3.0
# ...

# %%
# !mineru --version
# Out:
# mineru, version 2.7.6

# %%
import os

# Set global environment variables in Colab
os.environ["MINERU_FORMULA_ENABLE"] = "false"
os.environ["MINERU_TABLE_ENABLE"] = "false"

# %%
# !rm -r /content/outputs.zip

# %%
import os
import glob
import subprocess

# --- CONFIGURATION ---
DATASET_TYPE = "handwritten_en"   # Change to "handwritten_en" for English dataset
MODEL_NAME = "mineru"             # Model identifier for output organization

# --- DYNAMIC PATH SETTINGS ---
INPUT_FOLDER = os.path.join("data", "raw", DATASET_TYPE, "images")
BASE_OUTPUT_DIR = os.path.join("outputs", DATASET_TYPE, MODEL_NAME)


def run_mineru(file_path, output_dir):
    """
    Runs MinerU CLI on a file.

    Args:
        file_path (str): Path to image or PDF.
        output_dir (str): Directory to save output.
    """

    file_path = os.path.abspath(file_path)
    output_dir = os.path.abspath(output_dir)

    # Build command
    cmd = [
      "mineru",
      "-p", file_path,
      "-o", output_dir,
      "-b", "pipeline",  # Pipeline allows the -m and -l flags
      "-m", "ocr",       # FORCE ocr mode to bypass layout 'guessing'
      "-l", "ch_lite",   # Use the light model for faster/generic recognition
      "-f", "false",     # Disable formula parsing (prevents handwriting being 'math')
      "-t", "false"      # Disable table parsing
    ]

    print(f"Running command: {' '.join(cmd)}")

    result = subprocess.run(
        cmd,
        capture_output=True,
        text=True
    )

    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)

def run_batch_ocr():
    # Gather image and PDF files
    file_extensions = ("*.png", "*.jpg", "*.jpeg", "*.pdf")
    file_list = []

    for ext in file_extensions:
        file_list.extend(glob.glob(os.path.join(INPUT_FOLDER, ext)))

    if not file_list:
        print(f"No files found in: {os.path.abspath(INPUT_FOLDER)}")
        return

    print("="*40)
    print(f"STARTING BATCH PROCESS")
    print(f"Dataset: {DATASET_TYPE}")
    print(f"Model:   {MODEL_NAME}")
    print(f"Found:   {len(file_list)} files")
    print("="*40)

    # Process files
    for i, file_path in enumerate(file_list, 1):
        file_name = os.path.basename(file_path)
        print(f"\n[{i}/{len(file_list)}] Processing: {file_name}")

        run_mineru(file_path, BASE_OUTPUT_DIR)

    print("\n" + "="*40)
    print(f"Batch processing complete!")
    print(f"Results saved in: {os.path.abspath(BASE_OUTPUT_DIR)}")
    print("="*40)

if __name__ == "__main__":
    run_batch_ocr()
# Out:
# ...
# STARTING BATCH PROCESS
# Dataset: handwritten_en
# Model:   mineru
# Found:   20 files
# ...
#
# [1/20] Processing: handwritten_en_0014.jpg
# Running command: mineru -p /content/data/raw/handwritten_en/images/handwritten_en_0014.jpg -o /content/outputs/handwritten_en/mineru -b pipeline -m ocr -l ch_lite -f false -t false
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# 2026-03-22 07:20:33.953 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:129 - Batch 1/1: 1 pages/1 pages
# 2026-03-22 07:20:33.962 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:189 - GPU Memory: 15 GB, Batch Ratio: 8.
# ...

# %%
import os
import glob
import subprocess

# --- CONFIGURATION ---
DATASET_TYPE = "handwritten_zh"   # Change to "handwritten_en" for English dataset
MODEL_NAME = "mineru"             # Model identifier for output organization

# --- DYNAMIC PATH SETTINGS ---
INPUT_FOLDER = os.path.join("data", "raw", DATASET_TYPE, "images")
BASE_OUTPUT_DIR = os.path.join("outputs", DATASET_TYPE, MODEL_NAME)


def run_mineru(file_path, output_dir):
    """
    Runs MinerU CLI on a file.

    Args:
        file_path (str): Path to image or PDF.
        output_dir (str): Directory to save output.
    """

    file_path = os.path.abspath(file_path)
    output_dir = os.path.abspath(output_dir)

    # Build command
    cmd = [
      "mineru",
      "-p", file_path,
      "-o", output_dir,
      "-b", "pipeline",  # Pipeline allows the -m and -l flags
      "-m", "ocr",       # FORCE ocr mode to bypass layout 'guessing'
      "-l", "ch_lite",   # Use the light model for faster/generic recognition
      "-f", "false",     # Disable formula parsing (prevents handwriting being 'math')
      "-t", "false"      # Disable table parsing
    ]

    print(f"Running command: {' '.join(cmd)}")

    result = subprocess.run(
        cmd,
        capture_output=True,
        text=True
    )

    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)

def run_batch_ocr():
    # Gather image and PDF files
    file_extensions = ("*.png", "*.jpg", "*.jpeg", "*.pdf")
    file_list = []

    for ext in file_extensions:
        file_list.extend(glob.glob(os.path.join(INPUT_FOLDER, ext)))

    if not file_list:
        print(f"No files found in: {os.path.abspath(INPUT_FOLDER)}")
        return

    print("="*40)
    print(f"STARTING BATCH PROCESS")
    print(f"Dataset: {DATASET_TYPE}")
    print(f"Model:   {MODEL_NAME}")
    print(f"Found:   {len(file_list)} files")
    print("="*40)

    # Process files
    for i, file_path in enumerate(file_list, 1):
        file_name = os.path.basename(file_path)
        print(f"\n[{i}/{len(file_list)}] Processing: {file_name}")

        run_mineru(file_path, BASE_OUTPUT_DIR)

    print("\n" + "="*40)
    print(f"Batch processing complete!")
    print(f"Results saved in: {os.path.abspath(BASE_OUTPUT_DIR)}")
    print("="*40)

if __name__ == "__main__":
    run_batch_ocr()
# Out:
# ...
# STARTING BATCH PROCESS
# Dataset: handwritten_zh
# Model:   mineru
# Found:   20 files
# ...
#
# [1/20] Processing: handwritten_zh_0008.jpg
# Running command: mineru -p /content/data/raw/handwritten_zh/images/handwritten_zh_0008.jpg -o /content/outputs/handwritten_zh/mineru -b pipeline -m ocr -l ch_lite -f false -t false
# 2026-03-22 07:30:33.075 | INFO     | mineru.backend.pipeline.pipeline_analyze:doc_analyze:129 - Batch 1/1: 1 pages/1 pages
# 2026-03-22 07:30:33.077 | INFO     | mineru.backend.pipeline.pipeline_analyze:batch_image_analyze:189 - GPU Memory: 15 GB, Batch Ratio: 8.
# 2026-03-22 07:30:33.077 | INFO     | mineru.backend.pipeline.model_init:__init__:209 - DocAnalysis init, this may take some times......
#
# ...
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 13148.29it/s]
#
# ...
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 7121.06it/s]
#
# ...
# Fetching 1 files: 100%|██████████| 1/1 [00:00<00:00, 6678.83it/s]
# ...

# %%
# !zip -r mineru_outputs.zip /content/outputs
# Out:
#   adding: content/outputs/ (stored 0%)
#   adding: content/outputs/handwritten_zh/ (stored 0%)
#   adding: content/outputs/handwritten_zh/mineru/ (stored 0%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ (stored 0%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ocr/ (stored 0%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ocr/handwritten_zh_0001_layout.pdf (deflated 5%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ocr/handwritten_zh_0001_content_list.json (stored 0%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ocr/handwritten_zh_0001_middle.json (deflated 54%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ocr/handwritten_zh_0001_origin.pdf (deflated 5%)
#   adding: content/outputs/handwritten_zh/mineru/handwritten_zh_0001/ocr/handwritten_zh_0001.md (stored 0%)
# ...

# %% [markdown]
# ## Processing Time
# For English Handwritten Documents, 7 minutes is used to process 20 docuemnts. \
# For Chinese Handwritten Documents, 7 minutes is used to process 20 docuemnts.

# %% [markdown]
# ## References
# Gradio Url : https://huggingface.co/spaces/opendatalab/MinerU \
# CLI command: https://opendatalab.github.io/MinerU/usage/cli_tools/ \
